# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# # Bakgrund

# %% [markdown]
# Guldfynd överväger att utöka sortimentet med diamanter. Syftet med följande analys är att identifiera mönster och korrelationer för att kunna ge rekommendationer kring vilka diamanter som har högst potential för avkastning. Vi använder datasetet "diamonds.csv" innehållandes 50 000 observationer för att utföra vår analys. Nedan visas ett demo på datasetetes struktur och kolumner.

# %%
df = pd.read_csv('diamonds.csv')

df = df[(df['x'] > 0) & (df['y'] > 0) & (df['z'] > 0)]
df = df.dropna(subset=['x', 'y', 'z'])

cut_mapping = {
    'Ideal': 'Excellent',        # Högsta nivån
    'Premium': 'Excellent',      # Näst högsta
    'Very Good': 'Very Good',    # Behåll
    'Good': 'Good',              # Behåll
    'Fair': 'Fair',              # Behåll
    'Poor': 'Poor',              # Om det skulle finnas
    'Shallow': 'Very Good',      # Om dessa finns
    'Deep': 'Good',
    'Very Shallow': 'Fair',
    'Very Deep': 'Poor'
}


df['cut'] = df['cut'].astype(str).replace(cut_mapping)

# Filtrera bort
valid_cuts = ['Excellent', 'Very Good', 'Good', 'Fair', 'Poor']
df = df[df['cut'].isin(valid_cuts)]


cut_order = ['Poor', 'Fair', 'Good', 'Very Good', 'Excellent']
df['cut'] = pd.Categorical(df['cut'], categories=cut_order, ordered=True)


print("Unika värden i cut:\n", df['cut'].value_counts(dropna=False))


df.head(5)
# Out:
# Unika värden i cut:
#  cut
# Excellent    35325
# Very Good    12078
# Good          4902
# Fair          1609
# Poor             0
# Name: count, dtype: int64
#    Unnamed: 0  carat        cut color clarity  depth  table  price     x  \
# 0           1   0.23  Excellent     E     SI2   61.5   55.0  326.0  3.95
# 1           2   0.21  Excellent     E     SI1   59.8   61.0  326.0  3.89
# 2           3   0.23       Good     E     VS1   56.9   65.0  327.0  4.05
# 4           5   0.31       Good     J     SI2   63.3   58.0  335.0  4.34
# 5           6   0.24  Very Good     J    VVS2   62.8   57.0  336.0  3.94
#
#       y     z
# 0  3.98  2.43
# 1  3.84  2.31
# 2  4.07  2.31
# 4  4.35  2.75
# 5  3.96  2.48

# %% [markdown]
# Nedan följer övergriplig information om diamanter och dess kvalitetsattribut:
#
# Kvaliteten på diamanter bedöms utifrån de så kallade 4C: Carat, Cut, Color och Clarity.
#
# Carat mäter diamantens vikt. En carat är 0.2 gram.
#
# Cut beskriver hur väl diamanten är slipad och påverkar hur mycket den gnistrar. Kvalitetsnivåer: Fair, Good, Very Good, Premium, Ideal.
#
# Color bedöms på en skala från D (färglös, högst kvalitet) till J (svag gul ton).
#
# Clarity mäter hur fri diamanten är från inneslutningar och defekter, från IF (internally flawless) till I3 (inklusioner synliga för blotta ögat).
#
# Dessa faktorer påverkar både diamantens skönhet och värde.

# %% [markdown]
# # Datakvalite

# %% [markdown]
# Som avslutande inleding vill jag även uppmärksamma brister i datakvaliten:
# 1. Vissa värden i x, y, z kolumnerna innehåller inga värden/0. Utan dimensioner kan diamanten inte fysiskt existera. Dessa ska exkluderas i beräkningarna.
# 2. Vissa värden är icke numeriska. För att utföra beräkningar och eventuellt i framtiden träna en modell på datan bör vi omvandla datan till numeriska.
# 3. Blandade värden i cut kolumnen. Kan resultera i inkonsekventa resultat. Vi behöver omvandla värdena till ett enskilt klassificeringssystem.

# %% [markdown]
# # Analys

# %% [markdown]
# Vi börjar med att undersöka vilka variabler som påverkar priset mest. Enligt ovan har vi följande variabler att ta i beakt: carat, cut, color, clarity, depth, table, x, y, z. För att få en överblick av hur följande variabler påverkar priset kan vi skapa en korrelationsmatris. Korrelation visar hur starkt två variabler samverkar. Nedan följer 4 exempel:
#
# +1 = positiv korrelation (när den ena ökar, ökar den andra exakt lika mycket)
# 0 = ingen korrelation
# -1 = Perfekt negativ korrelation (när den ena ökar, minskar den andra exakt lika mycket).
# 0.86 = Stark positiv korrelation/samband men inte perfekt

# %% [markdown]
# # Korrelationer mellan pris och variabler

# %%
plt.figure(figsize=(10,8))
sns.heatmap(df[["price", "carat", "depth", "table", "x", "y", "z"]].corr(), annot=True, cmap="coolwarm")
plt.title("Korrelationsmatris - Pris med andra variabler")
plt.xlabel("X")  # x-axel
plt.ylabel("Y")  # y-axel
plt.show()

# %% [markdown]
# Kollar vi på x axelns pris och y axelns pris ser vi uppenbarligen att korrelationen är perfekt. När priset stiger, stiger priset. Låt oss kolla på några fler variabler
#
# Vid vänster botten ser vi att x, y och z variablerna har en relativt stark korrelation med priset. Enligt den informationen kan vi dra slutsatsen att diamanterna blir dyrare desto större de är eftersom x, y, z representerar stenens dimensioner. Carat (stenens tyngd) har också ett tydligt samband med stenens dimensioner.
#
# Vi kan också se att carat har en väldigt hög inverkan på priset: Med ett värde på 0.92 har vi nästan en perfekt korrelation. Detta innebär att dessa två variabler rör sig nästan helt i korrelation.
#
# Vad som slutligen går att utläsa är korrelation mellan t.ex depth och carat är nästan icke existerande. Alltså information vi kanske kan ignorera är de blåfärgade rutorna som presenterar låga korrelationer.

# %%
df_corr = df.copy()

# till numeriska
cut_order = ['Poor', 'Fair', 'Good', 'Very Good', 'Excellent']
color_order = ['J', 'I', 'H', 'G', 'F', 'E', 'D']
clarity_order = ['I1', 'SI2', 'SI1', 'VS2', 'VS1', 'VVS2', 'VVS1', 'IF']

df_corr['cut'] = df_corr['cut'].astype('category').cat.set_categories(cut_order, ordered=True).cat.codes
df_corr['color'] = df_corr['color'].astype('category').cat.set_categories(color_order, ordered=True).cat.codes
df_corr['clarity'] = df_corr['clarity'].astype('category').cat.set_categories(clarity_order, ordered=True).cat.codes

cols = ["price", "carat", "x", "y", "z", "cut", "color", "clarity"]

# värmekarta
plt.figure(figsize=(10, 8))
sns.heatmap(df_corr[cols].corr(), annot=True, cmap="coolwarm")
plt.title("Pris och kvalitetsattribut")
plt.xlabel("Variabel")
plt.ylabel("Variabel")
plt.show()

# %% [markdown]
# Vi ser även här där vi adderat fler variabler t.ex color, cut, clarity. Vi kan observera att varken clarity, color eller cut knappt tycks ha någon korrelation med pris alls.

# %% [markdown]
# # Regressionsplottar: för ökad tydlighet

# %%
sns.lmplot(data=df, x='carat', y='price', scatter_kws={'alpha':0.1})
plt.title("Pris vs Carat")
plt.show()

sns.lmplot(data=df, x='depth', y='price', scatter_kws={'alpha':0.1})
plt.title("Pris vs Depth")
plt.show()

sns.lmplot(data=df, x='table', y='price', scatter_kws={'alpha':0.1})
plt.title("Pris vs Table")
plt.show()

# %% [markdown]
# Ovan använder vi regressionsplottar för att jämföra korrelationen mellan numeriska värden och pris. Vi kan tydligt se att table och depth är relativt koncentrerade på samma värde i x axeln. Detta innebär då att samma table och depth kan ha helt olika priser. Det går inte att dra någon direkt slutsats om att det påverkar priset. Däremot finns det förmodligen andra faktorer i korrelation med table och depth som påverkar priset. Överst ser vi att carat och pris har en mycket tydligare korrelation.
#
# Låt oss ta en titt på de icke numeriska värdena också för att identifiera pris i kombination med variabeln. Se nedan.

# %% [markdown]
# # Boxplots/Lådagram - för att identifiera koncentrationen av pris beroende på variabler

# %%
# Boxplot för Cut
cut_order = ['Poor', 'Fair', 'Good', 'Very Good', 'Excellent']
df['cut'] = pd.Categorical(df['cut'], categories=cut_order, ordered=True)

sns.boxplot(data=df, x='cut', y='price', order=cut_order)
plt.title("Pris beroende på Cut")
plt.xticks(rotation=45)
plt.show()

# Boxplot för Color
color_order = ['J', 'I', 'H', 'G', 'F', 'E', 'D']
sns.boxplot(data=df, x='color', y='price', order=color_order)
plt.title("Pris beroende på Color")
plt.show()

# Boxplot för Clarity
clarity_order = ['I1', 'SI2', 'SI1', 'VS2', 'VS1', 'VVS2', 'VVS1', 'IF']
sns.boxplot(data=df, x='clarity', y='price', order=clarity_order)
plt.title("Pris beroende på Clarity")
plt.show()

# %% [markdown]
# Notera att värden saknas för premium och ideal för att
#
# För visuell represenation ordnar vi variablerna i ordning sämst till bäst för att förtydliga visualiseringen.
#
# Utifrån de 3 lådagramen ovan kan vi även här se att medianpriset är relativt koncentrerat oavsett vilken clarity, color och cut stenen har.
#
# Vi har dock en relativt lång övre 25 procentil och vissa extremvärden.för samtliga variabler. Visualiseringen ger oss ingen direkt klar data, snarare en överskådlig uppfattning om hur det ligger till.
#
# Vi kan dock förstå att spridningen är stor inom varje variabel och kategori vilket antyder att de återigen inte är starkt prispåverkande.
#
# Eftersom lådagrammen är sorterade i kvalitetsordning kan vi också se under "clarity" att många av de sämre "clarityn" har ett högre snittpris. Orsak kan vara att det är vanligare att stenar med högre carat också är av lite sämre kvalite.
#
# Vi gräver djupare i följande frågeställning senare: "Om diamantens clarity, color och cut ska tas i beakt vid investering." Kort observation: Förmodligen bör vi göra det även då det inte har en direkt inverkan på priset då det påverkar kundnöjdhet och marknadsföring.
#
# Nu när vi identifierat att den mest avgörande faktorn för stenens pris är caraten bör vi ta reda på vad som är snittpriset för repsketive tyngd/storlek. Baserat på det kan vi förhoppningsvis i framtiden med hjälp av predektorer identifiera extremvärden där det finns potential för hög ROI.
#
# Nedan tar vi reda på pris per carat.

# %%
bins = [0, 0.25, 0.5, 0.75, 1.0, 1.25, 1.5, 2.0, 2.5, 3.0, 3.5, 4.0, 5.0]
labels = ["0-0.25", "0.25-0.5", "0.5-0.75", "0.75-1.0", "1.0-1.25", "1.25-1.5", 
          "1.5-2.0", "2.0-2.5", "2.5-3.0", "3.0-3.5", "3.5-4.0", "4.0-5.0"]

df['carat_range'] = pd.cut(df['carat'], bins=bins, labels=labels)

# Skapa pivot-tabell: rad = carat_range, kolumn = tom (bara prisgenomsnitt per spann)
pivot_carat_price = df.pivot_table(index='carat_range', values='price', aggfunc='mean')

# Heatmap
sns.heatmap(pivot_carat_price, annot=True, fmt=".0f", cmap='YlOrRd', linewidths=0.5)
plt.title("Genomsnittspris per Caratintervall")
plt.xlabel("Pris")
plt.ylabel("Carat-intervall")
plt.show()
# Out:
# /var/folders/66/n7t02x9n3px6n956yn182btr0000gn/T/ipykernel_6962/240317625.py:8: FutureWarning: The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#   pivot_carat_price = df.pivot_table(index='carat_range', values='price', aggfunc='mean')

# %% [markdown]
# Ovan kan vi utläsa genomsnittspriset för respektive carat intervall. Endast utifrån heatmapen ovan hade vi kunnat fatta affärsmässiga beslut där vi ett visst intervall tittar på försäljningspriser under genomsnittet. Med stor sannolikhet hade detta kunnat leda till en avkastning.
#
# Med hjälp av sorteringen nedan kan vi också enkelt se vilka stenar som är billigast över 1 carat. Här hade vi definitivt tittat närmre om vi inte alls brydde os om cut, color, clarity osv. Däremot finns det en stor prisskillnad här om vi tittar på sorteringen nummer 2 som är sorterat högst pris till lägst.
#
# Den billigaste och dyraste stenen är nästan precis lika stora men det skiljer cirka $177 000. Förmodligen har kvaliteerna en större inverkan på priset än vad vi först trodde. Trots att det isolerat ej kan visualiseras så sker det i kombination av varandra.

# %%
df["price_per_carat"] = df["price"] / df["carat"]
bottom10 = df[df["carat"] >= 1].sort_values("price_per_carat").head(10)
bottom10[["carat", "cut", "color", "clarity", "price_per_carat"]]
# BOTTOM 10
# Out:
#        carat        cut color clarity  price_per_carat
# 41918   1.03       Fair     E      I1      1225.242718
# 45505   1.00  Excellent     J      I1      1681.000000
# 46575   1.00       Fair     J      I1      1784.000000
# 46784   1.00       Fair     I      I1      1805.000000
# 48090   1.00  Excellent     H      I1      1932.000000
# 52422   1.30       Fair     H      I1      1932.307692
# 48259   1.00       Fair     G      I1      1954.000000
# 48884   1.04       Fair     I      I1      1958.653846
# 49217   1.06  Very Good     G      I1      1962.264151
# 51292   1.20  Excellent     F      I1      1966.666667

# %%
# TOPP 10
top10 = df.sort_values('price_per_carat', ascending=False).head(10)
top10[['carat', 'cut', 'color', 'clarity', 'price_per_carat']]
# Out:
#        carat        cut color clarity  price_per_carat
# 27635   1.04  Very Good     D      IF     17828.846154
# 27530   1.07  Excellent     D      IF     17083.177570
# 27226   1.03  Excellent     D      IF     17077.669903
# 27457   1.07  Very Good     D      IF     16928.971963
# 26998   1.02  Very Good     D      IF     16764.705882
# 27349   1.07  Very Good     D      IF     16737.383178
# 27507   1.09  Very Good     D      IF     16725.688073
# 26660   1.00  Excellent     D      IF     16469.000000
# 26549   1.01  Excellent     D      IF     16073.267327
# 26483   1.00  Very Good     D      IF     16073.000000

# %% [markdown]
# För att skapa en indikation på det faktum att de "andra" variablerna, cut, color osv har en inverkan på priset kan vi isolera datan till nästan exakt 1 carat. I  lådagramet (clarity 1 carat) kan vi se att det finns en tydlig korrelation mellan pris och clarity. Återigen, detta avser endast ungefär 1 carat och lådagramet kanske ser helt annorlunda ut om man kikar på t.ex 0.5 carat eller hela spannet 0.1 - 5 carat.  (notera rubrikerna. Pris beroende på clarity 0.5, 1.5, 2.0)
#
# Även då det finns tydliga korrelationer mellan pris & cut/color så är den största förändringen i pris beroende på clarity om man bortser från carat. Vi kan dock se att i samtliga 3 caratintervaller så börjar priset plana ut vid WS3. alltså den 3:e bästa kvaliten på clarity. Om man nu kan få finare stenar för samma pengar bör detta vara något att undersöka mer av. Ideen börjar forma sig att skapa någon form av sorterings beräknare i streamlit som kikar på den lägre 25 procentilen när det kommer till clarityn och dess pris och samtidigt kombinera detta med att hitta ett värde lägre än genomsnittspriset per carat intervall. Se beräkning under "Hitta extremvärden i priser per carat"

# %%
df_1carat = df[(df['carat'] >= 0.99) & (df['carat'] <= 1.01)]
df_2carat = df[(df['carat'] >= 0.49) & (df['carat'] <= 0.51)]
df_3carat = df[(df['carat'] >= 1.49) & (df['carat'] <= 1.51)]
df_4carat = df[(df['carat'] >= 1.99) & (df['carat'] <= 2.01)]
df_5carat = df[(df['carat'] >= 0.1) & (df['carat'] <= 0.26)]

cut_order = ['Poor', 'Fair', 'Good', 'Very Good', 'Excellent']
sns.boxplot(data=df_1carat, x='cut', y='price', order=cut_order)
plt.title("Pris beroende på Cut (~1-carat)")
plt.show()

color_order = ['J', 'I', 'H', 'G', 'F', 'E', 'D']
sns.boxplot(data=df_1carat, x='color', y='price', order=color_order)
plt.title("Pris beroende på Color (~1-carat)")
plt.show()

clarity_order = ['I1', 'SI2', 'SI1', 'VS2', 'VS1', 'VVS2', 'VVS1', 'IF']
sns.boxplot(data=df_1carat, x='clarity', y='price', order=clarity_order)
plt.title("Pris beroende på Clarity (~1-carat)")
plt.show()

clarity_order = ['I1', 'SI2', 'SI1', 'VS2', 'VS1', 'VVS2', 'VVS1', 'IF']
sns.boxplot(data=df_2carat, x='clarity', y='price', order=clarity_order)
plt.title("Pris beroende på Clarity (~0.5-carat)")
plt.show()

clarity_order = ['I1', 'SI2', 'SI1', 'VS2', 'VS1', 'VVS2', 'VVS1', 'IF']
sns.boxplot(data=df_3carat, x='clarity', y='price', order=clarity_order)
plt.title("Pris beroende på Clarity (~1.5-carat)")
plt.show()

clarity_order = ['I1', 'SI2', 'SI1', 'VS2', 'VS1', 'VVS2', 'VVS1', 'IF']
sns.boxplot(data=df_4carat, x='clarity', y='price', order=clarity_order)
plt.title("Pris beroende på Clarity (~2-carat)")
plt.show()

clarity_order = ['I1', 'SI2', 'SI1', 'VS2', 'VS1', 'VVS2', 'VVS1', 'IF']
sns.boxplot(data=df_5carat, x='clarity', y='price', order=clarity_order)
plt.title("Pris beroende på Clarity (~0.25-carat)")
plt.show()

# %% [markdown]
# # Hitta extremvärden i priser per carat

# %% [markdown]
# Vi går tillbaka lite till grafen med genomsnittspris per carat men denna gången vill vi gräva djupare. Vi vill ta reda på vilka carat intervaller som kan vara billigare. För att göra detta behöver vi på något sätt beräkna medianen eller medelpriset för alla intervall. Detta ser vi resultatet av i lådagramet nedan. Målet är att hitta intervall där pris per carat är relativt lågt men totalpriset är fortfarande högt.
#
# För att göra detta behöver vi beräkna det faktiska carat priset oavsett hur mycket stenen väger. Genom att ta reda på detta kan vi ta reda på om stenen generellt sett är billigare än andra stenar i andra carat intervaller.

# %%
sns.boxplot(data=df, x='carat_range', y='price', order=labels)
plt.title("Pris beroende på Carat-intervall")
plt.xticks(rotation=45)
plt.xlabel("Carat-intervall")
plt.ylabel("Pris")
plt.tight_layout()
plt.show()

# %%
df = sns.load_dataset('diamonds')

# caratintervall
bins = [0, 0.25, 0.5, 0.75, 1.0, 1.25, 1.5, 2.0, 2.5, 3.0, 3.5, 4.0, 5.0]
labels = ["0-0.25", "0.25-0.5", "0.5-0.75", "0.75-1.0", "1.0-1.25", "1.25-1.5", 
          "1.5-2.0", "2.0-2.5", "2.5-3.0", "3.0-3.5", "3.5-4.0", "4.0-5.0"]
df['carat_range'] = pd.cut(df['carat'], bins=bins, labels=labels)


df['price_per_carat'] = df['price'] / df['carat']


pivot_ppc = df.pivot_table(index='carat_range', values='price_per_carat', aggfunc='mean')
pivot_total_price = df.pivot_table(index='carat_range', values='price', aggfunc='mean')

# topp 3-analys
combined = pivot_ppc.join(pivot_total_price, rsuffix='_total')
combined.columns = ['avg_price_per_carat', 'avg_total_price']
top3_value = combined.sort_values('avg_price_per_carat').head(3)

# Visa heatmap
sns.heatmap(pivot_ppc, annot=True, fmt=".0f", cmap='YlGnBu', linewidths=0.5)
plt.title("Genomsnittligt pris per carat per Caratintervall")
plt.xlabel("Pris per carat")
plt.ylabel("Carat-intervall")
plt.tight_layout()
plt.show()

top3_value
# Out:
# /var/folders/66/n7t02x9n3px6n956yn182btr0000gn/T/ipykernel_6962/2017836615.py:13: FutureWarning: The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#   pivot_ppc = df.pivot_table(index='carat_range', values='price_per_carat', aggfunc='mean')
# /var/folders/66/n7t02x9n3px6n956yn182btr0000gn/T/ipykernel_6962/2017836615.py:14: FutureWarning: The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#   pivot_total_price = df.pivot_table(index='carat_range', values='price', aggfunc='mean')
#              avg_price_per_carat  avg_total_price
# carat_range
# 0-0.25               2125.150582       506.132484
# 0.25-0.5             2345.594509       854.148344
# 0.5-0.75             3423.847969      2161.050480

# %% [markdown]
# Ovan kan vi se att priset per carat generellt sätt är billigare om hela stenen väger 0-0.25. De absolut dyraste stenarna per carat är de som befinner sig i 2.0-2.5 intervallet. Detta beror förmodligen på att det finns en korrelation mellan tillgång och efterfrågan. Större diamanter alltså 1> carat är mer sällsynt. Därför skjuter det i taket därefter. Mindre diamanter har inte lika hög efterfrågan men rent procentuellt kan de vara väldigt undervärderade.
#
# Baserat på ovan kan vi dra slutsatsen att priset inte stiger linjärt med caraten. Små diamanter är alltså mycket billigare per carat än sötrre. Pris per carat ökar snabbt runt jämna viktgränser eftersom köpare värdesätter runda siffror.
#
# Eftersom guldfynds främsta målgrupp är medelklassen kan vi snart dra slutsatsen att vi bör fokusera mer på de mindre diamanterna än de större.

# %% [markdown]
# Nu när vi har indikationer på att de stenarna med carat 0.25 generellt är billigast sett till caratpriset vill vi kombinera detta med de billigaste stenarna med hög clarity. Vi kan leta efter stenar med hög clarity som ligger i den lägre procentilen i pris dvs typ 450 dollar för den högsta kvaliten.
#
# Vi filtrerar på stenar mellan 0 och 0.25 carat med clarity IF med ett pris under 450 dollar.

# %%
filtered = df[
    (df['carat'] > 0) & (df['carat'] <= 0.25) &
    (df['clarity'] == 'IF') &
    (df['price'] < 450)
]

print(filtered[['carat', 'clarity', 'price']])
# Out:
#        carat clarity  price
# 30942   0.24      IF    449
# 31610   0.23      IF    369

# %%
sns.scatterplot(data=filtered, x='carat', y='price', hue='cut', style='color')
plt.title("Diamanter med clarity IF, <0.25 carat, pris < $450")
plt.xlabel("Carat")
plt.ylabel("Pris (USD)")
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.show()

# %% [markdown]
# Okej, vi har inte jättemycket o gå på här nu mer än 2 resultat. Dessa två stenar skulle däremot potentiellt vara värda att investera i. Vi behöver släppa lite på filtreringen men vi ska nu också ta de andra kvalitetsattributen i beakt.

# %% [markdown]
# Nu när vi vill fokusera mer på de mindre stenarna bör vi ta en extra vända över de andra kvalitetesattributen som cut och color. Vi använder samma lådagram som ovan fast kikar på 0.25 carat istället för 1 carat.

# %%
df_10carat = df[(df['carat'] >= 0.1) & (df['carat'] <= 0.26)]

cut_order = ['Poor', 'Fair', 'Good', 'Very Good', 'Excellent']
sns.boxplot(data=df_10carat, x='cut', y='price', order=cut_order)
plt.title("Pris beroende på Cut (~0.25-carat)")
plt.show()

color_order = ['J', 'I', 'H', 'G', 'F', 'E', 'D']
sns.boxplot(data=df_10carat, x='color', y='price', order=color_order)
plt.title("Pris beroende på Color (~0.25-carat)")
plt.show()

print("Antal matchande diamanter - cut :", len(cut_order))
print("Antal matchande diamanter - color:", len(color_order))
# Out:
# Antal matchande diamanter - cut : 5
# Antal matchande diamanter - color: 7

# %% [markdown]
# Intressant. Vi kan se att kvaliten i cut inte verkar påverka priset särskilt mycket däremot är stenens color billigare desto bättre kvalite den har. Detta kan dock bero på att det finns väldigt få värden. Vi kollar hur många stenar vi faktiskt får upp i denna filtreringen. Som vi kan se ovan har vi 5 respektive 7 stenar. Detta är inte mycket men det kanske räcker för att börja med.
#
# Nu vill vi ta reda på om det finns några som helst stenar som matchar samtliga krav, pris, carat, cut kvalite, color kvalite.

# %%
filtered = df[
    (df['carat'] <= 0.3) & 
    (df['clarity'] == 'IF') & 
    (df['color'] == 'D') & 
    (df['cut'] == 'Ideal') & 
    (df['price'] < 1000)
]

print("Antal matchande diamanter:", len(filtered))
# Out:
# Antal matchande diamanter: 1

# %%
print(filtered.index)
# Out:
# Index([35228], dtype='int64')

# %%
filtered_with_index = filtered.reset_index()
filtered_with_index[['index', 'carat', 'clarity', 'color', 'cut', 'price']]
# Out:
#    index  carat clarity color    cut  price
# 0  35228   0.27      IF     D  Ideal    893

# %% [markdown]
# Ovan har vi en lista på stenar i caratintervallet 0.25-0.3 i kombination med de bästa kvalitetsattributen. Priset hör till den övre procentilen i de flestas lådagram. Ändrar vi kvalitetsattributet color från D till e får vi en lista på 8

# %%
filtered = df[
    (df['carat'] <= 0.3) & 
    (df['clarity'] == 'IF') & 
    (df['color'] == 'E') & 
    (df['cut'] == 'Ideal') & 
    (df['price'] < 1000)
]

print("Antal matchande diamanter:", len(filtered))
# Out:
# Antal matchande diamanter: 8

# %%
filtered_with_index = filtered.reset_index()
filtered_with_index[['index', 'carat', 'clarity', 'color', 'cut', 'price']]
# Out:
#    index  carat clarity color    cut  price
# 0  33099   0.29      IF     E  Ideal    815
# 1  36488   0.30      IF     E  Ideal    943
# 2  36489   0.30      IF     E  Ideal    943
# 3  36490   0.30      IF     E  Ideal    943
# 4  36830   0.30      IF     E  Ideal    957
# 5  36831   0.30      IF     E  Ideal    957
# 6  36832   0.30      IF     E  Ideal    957
# 7  36833   0.30      IF     E  Ideal    957

# %% [markdown]
# Om vi kikar på diamant kalkylatorer är detta inga bra inköpspriser. Köper vi dessa stenar för 800 dollar > kommer vi gå med förlust. Vi behöver därför göra en avväjning på kvalite för att få ner priset och sedan sälja med vinst. Vi testar att strunta i color och cut

# %%
filtered = df[
    (df['carat'] <= 0.3) & 
    (df['clarity'] == 'IF') & 
    (df['price'] < 400)
]

print("Antal matchande diamanter:", len(filtered))
# Out:
# Antal matchande diamanter: 1

# %%
filtered_with_index = filtered.reset_index()
filtered_with_index[['index', 'carat', 'clarity', 'color', 'cut', 'price']]
# Out:
#    index  carat clarity color        cut  price
# 0  31610   0.23      IF     H  Very Good    369

# %% [markdown]
# Här har vi en sten som ligger under det beräknade marknadspriset enligt denna sidan: https://www.stonealgo.com/diamond-price-calculator/calc?a=1&b=0.3&c=4&d=7&e=3&f=4&g=4&h=5&i=0

# %% [markdown]
# Efter lite research i kombination med data ovan har jag funnit att color och clarity har en mindre påverkan på priset eftersom många kunder ändå inte kan se någon skillnad mellan färgskalan D till G vilket gör att vi kan göra bättre affärer på G diamanter. Även diamantes clarity ser VS1 och VS2 visuellt lika bra ut till lägre pris. Källa: https://www.brilliance.com/article/how-much-does-a-diamond-cost?utm_source=chatgpt.com
#
# Detta i kobmination med grafen om pris för olika kvaliteer i clarity och color har vi indikationer på att vi kan få en sten för billigare pris utan att göra ett enormt avkall på kvalite. Vi kommer hädan efter titta på stenar i:
# clarity: IF, VVS1
# color: E, F, G
# cut: Ideal
# Carat: 0.25-0.3
#
# Är detta segementet vi väljer att rikta in oss på blir målgruppen förmodligen medelklass som har mindre koll på stenars kvalite. Enligt nordsika preferenser vilket är marknaden guldfynd kommer att agera på föredras det mindre men kvalitativa stenar. Vi håller oss därför till stenar under 1 carat och prioriterar kvalitet.
#
# Vi använder informationen ovan och filtrerar:

# %%
filtered = df[
    (df['carat'] >= 0.25) & (df['carat'] <= 0.3) &
    (df['clarity'].isin(['IF', 'VVS1'])) &
    (df['color'].isin(['E', 'F', 'G'])) &
    (df['cut'] == 'Ideal') &
    (df['price'] < 700)
]

print("Antal matchande diamanter:", len(filtered))
filtered
# Out:
# Antal matchande diamanter: 49
#        carat    cut color clarity  depth  table  price     x     y     z  \
# 3053    0.27  Ideal     G      IF   61.6   57.0    566  4.18  4.21  2.58
# 6036    0.25  Ideal     F    VVS1   60.9   57.0    575  4.06  4.09  2.48
# 6378    0.25  Ideal     E    VVS1   61.2   57.0    576  4.08  4.12  2.51
# 8045    0.25  Ideal     G    VVS1   61.7   56.0    582  4.05  4.07  2.51
# 8046    0.25  Ideal     G    VVS1   62.6   55.0    582  4.03  4.04  2.52
# 8047    0.25  Ideal     G    VVS1   62.6   56.0    582  4.01  4.05  2.52
# 8049    0.25  Ideal     G      IF   61.1   57.0    582  4.06  4.07  2.48
# 8728    0.27  Ideal     E    VVS1   62.0   56.0    586  4.16  4.19  2.59
# 12703   0.26  Ideal     E    VVS1   62.0   56.0    599  4.09  4.13  2.55
# 12704   0.26  Ideal     E    VVS1   61.7   57.0    599  4.07  4.10  2.52
# 12707   0.26  Ideal     F    VVS1   61.6   57.0    599  4.08  4.10  2.52
# ...

# %%
# Filtrera alla diamanter till endast de med carat mellan 0 och 1
df_under_1ct = df[df['carat'] <= 0.5]

# Filtrera matchande diamanter inom 0.25–0.3 carat, med specifika villkor
filtered = df_under_1ct[
    (df_under_1ct['carat'] >= 0.25) & (df_under_1ct['carat'] <= 0.3) &
    (df_under_1ct['clarity'].isin(['IF', 'VVS1'])) &
    (df_under_1ct['color'].isin(['E', 'F', 'G'])) &
    (df_under_1ct['cut'] == 'Excellent') &
    (df_under_1ct['price'] < 700)
]

print("Antal matchande diamanter:", len(filtered))

# Rita scatterplot med alla diamanter under 1 carat i grått
plt.figure(figsize=(10, 6))
plt.scatter(df_under_1ct['carat'], df_under_1ct['price'], color='lightgray', label='Alla diamanter (<1 ct)', alpha=0.5)

# Lägg till filtrerade diamanter i röd färg
plt.scatter(filtered['carat'], filtered['price'], color='red', label='Matchande diamanter', alpha=0.8)

# Etiketter och titel
plt.xlabel('Carat')
plt.ylabel('Price')
plt.title('Pris vs Carat (0–1 ct) med filtrerade diamanter markerade')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Antal matchande diamanter: 58

# %% [markdown]
# Baserat på datan vi får ut skapar vi en scatterplott som visar dessa stenar på intervallet mellan 0.20-0.5 carat. Vi kan se att de är relativt koncentrerat men samtidigt att det finns stenar som uppfyller samma kriterier men som vi kan få billigare. Under 0.28 carat kan vi t.ex se att det finns en diamant som är billigare än resten av ovan. Vi tar informationen ovan och beräknar medianen för respektive caratintervall för att sedan kunna filtrera ut de stenar som befinner sig under medianen. Här har vi en potentiell köpindikation där potential för avkastning är hög.

# %%
# Skapa 0.01-intervaller från 0.25 till 0.3
bins = np.arange(0.25, 0.31, 0.01)  # ger [0.25, 0.26, ..., 0.30]
labels = [f"{round(bins[i], 2)}–{round(bins[i+1], 2)}" for i in range(len(bins) - 1)]

# Skapa ny kolumn i filtrerat dataset
filtered['carat_interval'] = pd.cut(filtered['carat'], bins=bins, labels=labels, include_lowest=True)

# Räkna medianpris för varje intervall
median_prices = filtered.groupby('carat_interval')['price'].median().reset_index()

# Visa tabellen
print(median_prices)
# Out:
#   carat_interval  price
# 0      0.25–0.26  599.0
# 1      0.26–0.27  624.5
# 2      0.27–0.28  650.0
# 3      0.28–0.29  673.0
# 4       0.29–0.3  684.0
# /var/folders/66/n7t02x9n3px6n956yn182btr0000gn/T/ipykernel_6962/3510780120.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered['carat_interval'] = pd.cut(filtered['carat'], bins=bins, labels=labels, include_lowest=True)
# /var/folders/66/n7t02x9n3px6n956yn182btr0000gn/T/ipykernel_6962/3510780120.py:9: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
# ...

# %%
plt.figure(figsize=(10, 5))
plt.bar(median_prices['carat_interval'], median_prices['price'], color='red', alpha=0.8)
plt.xlabel("Carat-intervall (0.01 steg)")
plt.ylabel("Medianpris")
plt.title("Medianpris för filtrerade diamanter (0.25–0.30 ct)")
plt.grid(axis='y')
plt.show()

# %%
median_dict = median_prices.set_index('carat_interval')['price'].to_dict()

5% under medianen för sin grupp
below_median_10 = []

for idx, row in filtered.iterrows():
    interval = row['carat_interval']
    price = row['price']
    
    if pd.isna(interval) or interval not in median_dict:
        continue
    
    median = median_dict[interval]
    if price < median * 0.95:
        below_median_10.append({
            'index': idx,
            'carat': row['carat'],
            'price': price,
            'interval': interval,
            'median': median,
            'threshold_90pct': median * 0.9
        })


df_below_median_10 = pd.DataFrame(below_median_10)
print(df_below_median_10)
# Out:
#    index  carat  price   interval  median  threshold_90pct
# 0   3053   0.27  566.0  0.26–0.27   624.5           562.05
# 1   8728   0.27  586.0  0.26–0.27   624.5           562.05
# 2  15695   0.29  607.0  0.28–0.29   673.0           605.70
# 3  15696   0.29  607.0  0.28–0.29   673.0           605.70
# 4  44651   0.28  522.0  0.27–0.28   650.0           585.00

# %% [markdown]
# Ovan har vi en lista på 5 diamanter som befinner sig i det korrekta caratintervallet/mest diamant för pengarna och filtrerat efter de kvalitetsattribut som är mest relevanta för den nordiska köparen vilket är en budget diamant utan att göra avkall på kvalite/utseende.

# %% [markdown]
# # Executive summary
